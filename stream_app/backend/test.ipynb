# %%
str="Sheena loves eating apple and mango. Her sister also loves eating apple and mango."
list_str=str.split()
ans_dict={}

# %%
for w in list_str:
    if w not in ans_dict.keys():
        ans_dict[w]=0
    ans_dict[w]+=1

# %%
ans_dict
# Out:
# {'Sheena': 1,
#  'loves': 2,
#  'eating': 2,
#  'apple': 2,
#  'and': 2,
#  'mango.': 2,
#  'Her': 1,
#  'sister': 1,
#  'also': 1}
